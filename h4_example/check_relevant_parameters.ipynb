# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os


def read_csv(r):
    df = pd.read_csv(f"ai_data/{r}.csv")
    df['r'] = float(r[1:])
    return df


df = pd.concat([read_csv(r) for r in ["r2.4", "r2.6", "r2.8", "r3.0", "r3.2", "r3.4", "r3.6", "r3.8", "r4.0", "r4.4", "r4.8", "r5.0"]])

# %%
dfvar = df[df.state < 10].groupby(['r']).var()
dfvar
# Out:
#        energy     state        E0         t     tdiag         J    J_diag  \
# r
# 2.4  0.019720  9.166667  0.091199  0.576418  0.074447  1.131364  0.463290
# 2.6  0.016632  9.166667  0.002128  1.291902  0.097554  1.809074  0.708905
# 2.8  0.014067  9.166667  0.001317  1.243575  0.059184  1.967338  0.873320
# 3.0  0.012702  9.166667  0.000801  1.184834  0.035020  2.143524  1.081046
# 3.2  0.011993  9.166667  0.000551  1.120144  0.024315  2.333903  1.323776
# 3.4  0.011986  9.166667  0.000441  1.059286  0.017357  2.536302  1.577869
# 3.6  0.012417  9.166667  0.000414  1.006609  0.013168  2.739631  1.820426
# 3.8  0.013176  9.166667  0.000431  0.962837  0.010173  2.933597  2.034879
# 4.0  0.014153  9.166667  0.000613  0.945215  0.000565  3.063059  2.200962
# 4.4  0.016272  9.166667  0.000600  0.856878  0.002394  3.338972  2.462677
# 4.8  0.018778  9.166667  0.000658  0.829431  0.015505  3.516615  2.619538
# 5.0  0.020077  9.166667  0.000708  0.823943  0.030835  3.575058  2.670493
#
# ...
